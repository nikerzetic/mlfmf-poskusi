# %%
import networkx as nx
import node2vec as n2v
import matplotlib.pyplot as plt
import helpers

# %%
entries, network = helpers.load_library("stdlib")
# Out:
# Loading entries ...
# ...
# 100%|██████████| 16483/16483 [03:38<00:00, 75.27it/s]
# Loaded 16483 entries.
# Loading network ...
# Loaded G(V, E) where (|V|, |E|) = (16855, 242484)

# %%
# pos = nx.nx_pydot.graphviz_layout(network, prog="dot")
# pos = nx.kamada_kawai_layout(G)
pos = nx.spring_layout(network, iterations=10, seed=42)

# %%
plt.figure(figsize=(20, 20), dpi=100)
nx.draw_networkx(network, pos, with_labels=False, node_size=1000, font_size=9)
