# %%
import visualisation as vis

# %%
vis.draw_from_dag_file("stdlib\\entries\\Agda.Builtin.Bool_0002.dag")

# %%
vis.draw_from_dag_file("stdlib\\entries\\Agda.Builtin.Char_0006.dag")

# %%
vis.draw_from_dag_file("stdlib\\entries\\Agda.Builtin.Float_0013.dag")

# %%
vis.draw_from_dag_file("stdlib\\entries\\Data.Vec.Base_0000.dag")

# %%
vis.draw_from_dag_file("stdlib\\entries\\Data.Sum.Base_0000.dag")

# %%
vis.draw_from_dag_file("stdlib\\entries\\Data.Nat.Base_0001.dag")

# %%
leaves = vis.get_dag_leaves("stdlib\\entries\\Data.List.Relation.Binary.Lex_0011.dag")
for node in leaves:
    print(node, end=", ")
print()
for node in leaves:
    if not node or node.isnumeric():
        continue
    print(node)
# Out:
# Data.List.Relation.Binary.Lex._._.resp² 218, 0, 0, Agda.Primitive.Level 14, 0, 0, Agda.Primitive.Level 14, 0, 0, Agda.Primitive.Level 14, 2, 1, 0, 2, 2, 3, 2, 1, 1, 0, 4, 3, 2, 4, 3, Relation.Binary.Core.Rel 38, , , 4, , , 1, , , 3, 5, 4, 3, 5, 3, Relation.Binary.Core.Rel 38, , , 5, , , 2, , , 3, 6, 5, 4, 6, 5, Relation.Binary.Structures.IsEquivalence 26, , , 6, , , 5, , , 3, , , 1, 6, 5, 4, 6, 5, 4, Relation.Binary.Definitions._Respectsʳ_ 308, , , 6, , , 3, , , 6, , , 3, , , 4, , , 5, , , 0, , , 1, 6, 5, 4, 6, 5, 4, Relation.Binary.Definitions._Respectsˡ_ 318, , , 6, , , 3, , , 6, , , 3, , , 4, , , 5, , , 0, , , 1, 6, 5, 4, 6, Agda.Builtin.List.List 10, , , 6, , , 3, 7, 6, 5, Relation.Binary.Definitions._Respects_ 302, , , 7, , , Agda.Builtin.List.List 10, , , 7, , , 4, , , 7, 6, 5, , , 7, 6, , , Function.Base.flip 116, , , 7, , , 7, , , 7, 6, 5, , , Agda.Builtin.List.List 10, , , 7, , , 4, , , Agda.Builtin.List.List 10, , , 7, , , 4, , , Agda.Primitive._⊔_ 26, , , Agda.Primitive._⊔
# ...
